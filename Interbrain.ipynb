# %% [markdown]
# <a href="https://colab.research.google.com/github/Godyguns/1822-Almacenando-Datos-En-El-Navegador/blob/projectoInicial/Interbrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
global f 
f = 0
  
def t_peli(): 
    global f 
    f = f+1
    print("que pelicula quieres ver?") 
    print("1,Matrix ") 
    print("2,Thor ") 
    print("3,Constantine") 
    print("4,atras ") 
    pelicula = int(input("elige tu pelicula: ")) 
    if pelicula == 4: 
      
      centro() 
      teatro() 
      return 0
    if f == 1: 
      teatro() 
  
def teatro(): 
    print("en que pantalla quieres ver la pelicula: ") 
    print("1,PANTALLA XD") 
    print("2,PANTALLA 3D") 
    print("3,PANTALLA 7D") 
    a = int(input("elige tu pantalla: ")) 
    boleto = int(input("número de boletos que desea?: ")) 
    momento(a) 
  
def momento(a): 
    tiempo1 = { 
        
        "1": "14:00", 
        "2": "16:45", 
        "3": "18:00", 
        "4": "20:00"
    } 
    tiempo2 = { 
        
        "1": "14:30", 
        "2": "16:00", 
        "3": "18:00", 
        "4": "21:00"
    } 
    tiempo3 = { 
        
        "1": "13:00", 
        "2": "16:00", 
        "3": "19:00", 
        "4": "20:00"
    } 
    if a == 1: 
        print("elige el horario:") 
        print(tiempo1) 
        t = input("selecciona tu hora:") 
        x = tiempo1[t] 
        print(f"¡GENIAL!, disfruta de la película a las {x}hs.") 
    elif a == 2: 
        print("elige el horario:") 
        print(tiempo2) 
        t = input("selecciona tu hora:") 
        x = tiempo2[t] 
        print(f"¡GENIAL!, disfruta de la película a las {x}hs.") 
    elif a == 3: 
        print("elige el horario:") 
        print(tiempo3) 
        t = input("selecciona tu hora:") 
        x = tiempo3[t] 
        print(f"¡GENIAL!, disfruta de la película a las {x}hs.") 
    return 0
  
  
def pelicula(teatro): 
    if teatro == 1: 
        t_peli() 
    elif teatro == 2: 
        t_peli() 
    elif teatro == 3: 
        t_peli() 
    elif teatro == 4: 
        ciudad() 
    else: 
        print("mala elección") 
  
  
def centro(): 
    print("En que cine quieres ver la pelicula? ") 
    print("1,Village") 
    print("2,Cinema Center") 
    print("3,Palmares") 
    print("4,atras") 
    a = int(input("elige tu opción: ")) 
    pelicula(a) 
    return 0
  
def ciudad(): 
    print("Hola bienvenido a la reserva de entradas para el cine: ") 
    print("¿Dónde quieres ver la película?:") 
    print("1,Mendoza ") 
    print("2,San Juan ") 
    print("3,San luis ") 
    lugar = int(input("elige tu opción: ")) 
    if lugar == 1: 
      centro() 
    elif lugar == 2: 
      centro() 
    elif lugar == 3: 
      centro() 
    else: 
      print("Mala decisión") 
  
  
ciudad()
# Out:
# Hola bienvenido a la reserva de entradas para el cine:
# ¿Dónde quieres ver la película?:
# 1,Mendoza
# 2,San Juan
# 3,San luis
# elige tu opción: 1
# En que cine quieres ver la pelicula?
# 1,Village
# 2,Cinema Center
# 3,Palmares
# 4,atras
# elige tu opción: 1
# que pelicula quieres ver?
# 1,Matrix
# 2,Thor
# 3,Constantine
# 4,atras
# elige tu pelicula: 1
# en que pantalla quieres ver la pelicula:
# 1,PANTALLA XD
# 2,PANTALLA 3D
# 3,PANTALLA 7D
# elige tu pantalla: 2
# número de boletos que desea?: 2
# elige el horario:
# {'1': '14:30', '2': '16:00', '3': '18:00', '4': '21:00'}
# selecciona tu hora:2
# ¡GENIAL!, disfruta de la película a las 16:00hs.
